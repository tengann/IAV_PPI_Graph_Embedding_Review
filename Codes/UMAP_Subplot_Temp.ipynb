# %%
import matplotlib.pyplot as plt
import glob

# %%
### Create a list of directories
img_dir = './umap_plots/Graph/'
# img_dir = './umap_plots/Protein/'
# img_dir = './umap_plots/'

### Extract the image paths into a list
# All files and directories ending with .png and that don't begin with a dot:
files = glob.glob(img_dir + "*.png")
files
# print(glob.glob(img_dir + "*.png"))
# Out:
# ['./umap_plots/Graph\\1 nSNE_K128_B0.png',
#  './umap_plots/Graph\\2 nSNE_K128_B0.005.png',
#  './umap_plots/Graph\\3 nSNE_K128_B0.05.png',
#  './umap_plots/Graph\\4 nSNE_K128_B0.5.png',
#  './umap_plots/Graph\\5 nSNE_K128_B1.png']

# %%
## Graph Embedding
# plt_titles = ['deepwalk', 'node2vec', 'node2vec+', 'struc2vec', 'ripple2vec',
#              'LINE', 'SDNE', 'VAE', 'GraRep']

plt_titles = ['β=0', 'β=0.005', 'β=0.05', 'β=0.5', 'β=1']

## Protein Embedding
# plt_titles = ['AAC', 'DPC', 'C/T/D', 'QSOrder', 'APAAC', 'CT', 'NMBroto']

## 
# plt_titles = ['SDNE', 'node2vec+', 'struc2vec', 'APAAC', 'AAC', 'ripple2vec', 'LINE', 'QSOrder',
#               'node2vec', 'deepwalk', 'NMBroto', 'CT', 'GraRep', 'DPC', 'VAE', 'C/T/D']

# %%
# create the figure
# fig, axs = plt.subplots(nrows=4, ncols=4, figsize=(16, 16))
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(10, 10))

# flatten the axis into a 1-d array to make it easier to access each axes
axs = axs.flatten()

# iterate through and enumerate the files, use i to index the axes
for i, file in enumerate(files):
    
    # read the image in
    pic = plt.imread(file)

    # add the image to the axes
    axs[i].imshow(pic)

    # add an axes title; .stem is a pathlib method to get the filename
    axs[i].set(title=plt_titles[i])

# remove the x and y ticks
for ax in axs:
    ax.set_xticks([])
    ax.set_yticks([])

# %%
# create the figure
fig, axs = plt.subplots(nrows=3, ncols=3, figsize=(15, 15))

# flatten the axis into a 1-d array to make it easier to access each axes
axs = axs.flatten()

# iterate through and enumerate the files, use i to index the axes
for i, file in enumerate(files):
    
    # read the image in
    pic = plt.imread(file)

    # add the image to the axes
    axs[i].imshow(pic)

    # add an axes title; .stem is a pathlib method to get the filename
    axs[i].set(title=plt_titles[i])

# remove the x and y ticks
for ax in axs:
    ax.set_xticks([])
    ax.set_yticks([])
    
# Hide axs, Protein only
# fig.delaxes(axs[7])
# fig.delaxes(axs[8])

# %%
## LINE (proximity) & nSNE

# create the figure
# fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(15, 5)) ## LINE
fig, axs = plt.subplots(nrows=1, ncols=5, figsize=(20, 15)) ## nSNE

# flatten the axis into a 1-d array to make it easier to access each axes
axs = axs.flatten()

# iterate through and enumerate the files, use i to index the axes
for i, file in enumerate(files):
    
    # read the image in
    pic = plt.imread(file)

    # add the image to the axes
    axs[i].imshow(pic)

    # add an axes title; .stem is a pathlib method to get the filename
    axs[i].set(title=plt_titles[i])

# remove the x and y ticks
for ax in axs:
    ax.set_xticks([])
    ax.set_yticks([])
    
# Hide axs, Protein only
# fig.delaxes(axs[7])
# fig.delaxes(axs[8])

# %%
# fig, ax = umap.plot.plt.subplots(2, 2, figsize=(12,12))
# umap.plot.points(ordinal_mapper, labels=diamonds["color"], ax=ax[0,0])
# umap.plot.points(ordinal_mapper, labels=diamonds["clarity"], ax=ax[0,1])
# umap.plot.points(ordinal_mapper, labels=diamonds["cut"], ax=ax[1,0])
# umap.plot.points(ordinal_mapper, values=diamonds["price"], cmap="viridis", ax=ax[1,1])
